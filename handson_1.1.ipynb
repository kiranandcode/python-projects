# %% [markdown]
# # Hands On Machine Learning with Tensorflow and ScikitLearn
#
# While going through the hands on machine learning book, I've decided to type up some of the snippets I find here into a notebook, as it'll help gain familiarity with the framework and prepare me for the final year project.
#
#
# We'll start by doing some simple linear regression.
# Before we do anything, we need to pull in the usual imports:

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
from sklearn.linear_model import LinearRegression

# %% [markdown]
# To construct the dataset, we'll just use load it in as usual:

# %%
oecd_bli = pd.read_csv("../oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv("../gdp_per_capita.csv", thousands=',', delimiter='\t', encoding='latin1', na_values='n/a')

# %%
gdp_per_capita
# Out:
#                                                Country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                               Angola
# 4                                  Antigua and Barbuda
# 5                                            Argentina
# 6                                              Armenia
# 7                                            Australia
# 8                                              Austria
# 9                                           Azerbaijan
# 10                                         The Bahamas
# 11                                             Bahrain
# 12                                          Bangladesh
# 13                                            Barbados
# 14                                             Belarus
# 15                                             Belgium
# ...

# %%
X = np.c_[gdp_per_capita["2015"]]
y = np.c_[oecd_bli["Value"]]

# %%
# Out:
# array([], dtype=float64)

# %% [markdown]
# Now, to perform ols, we'll just use sklearn:

# %%
model = sklearn.linear_model.LinearRegression()

model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ffab386df74b> in <module>
#       1 model = sklearn.linear_model.LinearRegression()
#       2
# ----> 3 model.fit(X,y)
#
# ~/.local/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/.local/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %% [markdown]
# Finally, we can view the attributes of our learned model:

# %%
(X_new = [[22587]] # Prediction for Cyptus
 model.predict(X_new)
# Out:
# True

# %%
Now, this is cool and all, but here we're really interested in getting a real-world model out of this.
Clearly, to do this, we'll need to introduce some kind of api for working with this.

In our case, we'll do it via the command line
